# %% [markdown]
# ## Week 11-2 Practice

# %% [markdown]
# ### Problem 1: Implementing an objective function in NumPy and PyTorch
# Implement two Python functions that implements the mathematical functions $f(x) = 3x^\intercal x - x_1 - 4$. One function should work for $x$ a `numpy.ndarray` and the other should work for $x$ a `torch.FloatTensor`.

# %%
# !pip install torch torchvision torchaudio
print(torch.__version__)
# Out:
# Requirement already satisfied: torch in c:\anaconda\lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\anaconda\lib\site-packages (0.25.0)
# Requirement already satisfied: torchaudio in c:\anaconda\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in c:\anaconda\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\anaconda\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\anaconda\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\anaconda\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\anaconda\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\anaconda\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: setuptools in c:\anaconda\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\anaconda\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\anaconda\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\anaconda\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\anaconda\lib\site-packages (from jinja2->torch) (3.0.2)
# 2.10.0+cpu

# %%
print(torch.__version__)
# Out:
# 2.10.0+cpu

# %%
import torch
import numpy as np


def f_numpy(x):
    # YOUR CODE HERE
    return 3 * np.dot(x,x) - x[0] - 4
    #raise NotImplementedError()


def f_torch(x):
    return 3 * torch.dot(x,x) - x[0] -4
    # YOUR CODE HERE
    #raise NotImplementedError()

# %%
assert abs(f_numpy(np.zeros(4)) + 4) < 1e-6
assert abs(f_numpy(np.ones(2)) - 1) < 1e-6

assert abs(f_torch(torch.zeros(4)) + 4) < 1e-6
assert abs(f_torch(torch.ones(2)) - 1) < 1e-6

x0 = (1, -2, 3, 4, 5)
assert abs(f_numpy(np.array(x0)) - f_torch(torch.Tensor(x0))) < 1e-6

# %% [markdown]
# ### Problem 2: Computing gradients manually and automatically
# Implement functions to compute the gradient of $f$ at $x$ using numpy and PyTorch. Use autodiff for the latter.

# %%
def f_grad_numpy(x):
    # YOUR CODE HERE
    raise NotImplementedError()


def f_grad_torch(x):
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
def finite_diff(x, v):
    return (f_numpy(x + v) - f_numpy(x - v)) / (2 * np.linalg.norm(v))


x = np.ones(2)
v0 = 1e-4 * np.array([1, 0])
assert abs(finite_diff(x, v0) - f_grad_numpy(x)[0]) < 1e-2
v1 = 1e-4 * np.array([0, 1])
assert abs(finite_diff(x, v1) - f_grad_numpy(x)[1]) < 1e-2

np.random.seed(42)
for i in range(10):
    x2 = np.random.randn(5)
    v2 = np.random.randn(5)
    v2 = v2 / np.linalg.norm(v2)
    observed = finite_diff(x2, 1e-4 * v2)
    derived_vec = f_grad_numpy(x2)
    derived = derived_vec.dot(v2)
    assert abs(observed - derived) < 1e-2

xt = torch.tensor(x, requires_grad=True)
diff = f_grad_torch(xt).numpy() - f_grad_numpy(x)
assert np.linalg.norm(diff) < 1e-6
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[18], line 7
#       5 x = np.ones(2)
#       6 v0 = 1e-4 * np.array([1, 0])
# ----> 7 assert abs(finite_diff(x, v0) - f_grad_numpy(x)[0]) < 1e-2
#       8 v1 = 1e-4 * np.array([0, 1])
#       9 assert abs(finite_diff(x, v1) - f_grad_numpy(x)[1]) < 1e-2
#
# Cell In[17], line 3, in f_grad_numpy(x)
#       1 def f_grad_numpy(x):
#       2     # YOUR CODE HERE
# ----> 3     raise NotImplementedError()
#
# NotImplementedError:
